# %%
import config
import json
from matplotlib import pyplot as plt
from urllib.request import urlopen
import pandas as pd
import ast
import datetime
import seaborn as sns
import numpy as np
pd.set_option('display.max_colwidth', None)

# %%
API_KEY = config.api_key

# %%
def members_to_df(url):
    response = urlopen(url)
    response_content = response.read().decode('utf-8')
    responseJson = json.loads(response_content)
    df = pd.DataFrame.from_records(responseJson['members'])

    while("next" in responseJson['pagination'].keys()):
        next_url = responseJson['pagination']['next'] + f"&api_key={API_KEY}"
        response = urlopen(next_url)
        response_content = response.read().decode('utf-8')
        responseJson = json.loads(response_content)
        df_i = pd.DataFrame.from_records(responseJson['members'])
        df = pd.concat([df,df_i])
    
    return df

# %%
members = members_to_df(f'https://api.congress.gov/v3/member?limit=250&api_key={API_KEY}')

# %%
members.columns
# Out:
# Index(['bioguideId', 'depiction', 'name', 'partyName', 'state', 'terms',
#        'updateDate', 'url', 'district'],
#       dtype='object')

# %%
members.head()
# Out:
#   bioguideId  \
# 0    M001190
# 1    W000253
# 2        NaN
# 3    E000071
# 4    V000134
#
#                                                                                                                                                                                                                                                     depiction  \
# 0                                                                                                                                     {'attribution': '<p>Official U.S. Senate Photo</p>', 'imageUrl': 'https://www.congress.gov/img/member/m001190_200.jpg'}
# 1  {'attribution': '<a href="http://www.senate.gov/artandhistory/history/common/generic/Photo_Collection_of_the_Senate_Historical_Office.htm">Courtesy U.S. Senate Historical Office</a>', 'imageUrl': 'https://www.congress.gov/img/member/w000253_200.jpg'}
# 2                                                                                                                                                                                                                                                         NaN
# 3                                                                                                                                          {'attribution': 'Image courtesy of the Member', 'imageUrl': 'https://www.congress.gov/img/member/e000071_200.jpg'}
# 4                                                                                                                                                                                                                                                         NaN
#
#                       name   partyName        state  \
# 0        Mullin, Markwayne  Republican     Oklahoma
# 1  Weicker, Lowell P., Jr.  Republican  Connecticut
# 2                      NaN         NaN          NaN
# 3             Ellzey, Jake  Republican        Texas
# 4          Van Duyne, Beth  Republican        Texas
#
#                                                                                                                                                 terms  \
# 0                   {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2013}, {'chamber': 'Senate', 'startYear': 2023}]}
# 1  {'item': [{'chamber': 'House of Representatives', 'endYear': 1971, 'startYear': 1969}, {'chamber': 'Senate', 'endYear': 1989, 'startYear': 1973}]}
# 2                                                                                                                                                 NaN
# 3                                                                              {'item': [{'chamber': 'House of Representatives', 'startYear': 2021}]}
# 4                                                                              {'item': [{'chamber': 'House of Representatives', 'startYear': 2021}]}
#
#              updateDate  \
# 0  2023-07-10T19:23:09Z
# 1  2023-06-28T18:01:33Z
# 2                   NaN
# 3  2023-06-27T20:12:36Z
# 4  2023-06-27T20:12:36Z
#
#                                                       url  district
# 0  https://api.congress.gov/v3/member/M001190?format=json       NaN
# 1  https://api.congress.gov/v3/member/W000253?format=json       NaN
# 2                                                     NaN       NaN
# 3  https://api.congress.gov/v3/member/E000071?format=json       6.0
# 4  https://api.congress.gov/v3/member/V000134?format=json      24.0

# %%
members2 = members.filter(items=['bioguideId','name','terms']).dropna()
members2
# Out:
#    bioguideId                     name  \
# 0     M001190        Mullin, Markwayne
# 1     W000253  Weicker, Lowell P., Jr.
# 3     E000071             Ellzey, Jake
# 4     V000134          Van Duyne, Beth
# 5     S001159      Strickland, Marilyn
# ..        ...                      ...
# 11    F000229      Flynt, John J., Jr.
# 12    F000218          Flowers, Walter
# 13    F000215         Florio, James J.
# 14    F000209         Flood, Daniel J.
# 15    F000208        Flippo, Ronnie G.
#
#                                                                                                                                                                                                                                                 terms
# 0                                                                                                                   {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2013}, {'chamber': 'Senate', 'startYear': 2023}]}
# 1                                                                                                  {'item': [{'chamber': 'House of Representatives', 'endYear': 1971, 'startYear': 1969}, {'chamber': 'Senate', 'endYear': 1989, 'startYear': 1973}]}
# 3                                                                                                                                                                              {'item': [{'chamber': 'House of Representatives', 'startYear': 2021}]}
# 4                                                                                                                                                                              {'item': [{'chamber': 'House of Representatives', 'startYear': 2021}]}
# 5                                                                                                                                                                              {'item': [{'chamber': 'House of Representatives', 'startYear': 2021}]}
# ..                                                                                                                                                                                                                                                ...
# 11                                                                                                                                                            {'item': [{'chamber': 'House of Representatives', 'endYear': 1979, 'startYear': 1953}]}
# 12                                                                                                                                                            {'item': [{'chamber': 'House of Representatives', 'endYear': 1979, 'startYear': 1969}]}
# 13                                                                                                                                                            {'item': [{'chamber': 'House of Representatives', 'endYear': 1991, 'startYear': 1975}]}
# 14  {'item': [{'chamber': 'House of Representatives', 'endYear': 1947, 'startYear': 1945}, {'chamber': 'House of Representatives', 'endYear': 1953, 'startYear': 1949}, {'chamber': 'House of Representatives', 'endYear': 1981, 'startYear': 1955}]}
# 15                                                                                                                                                            {'item': [{'chamber': 'House of Representatives', 'endYear': 1991, 'startYear': 1977}]}
#
# [2515 rows x 3 columns]

# %%
members2.to_csv("C://Users//User//Desktop//congress//data//members.csv",index=False)

# %%
df = pd.read_csv("C://Users//User//Desktop//congress//data//members.csv",index_col='bioguideId')
df.head(3)
# Out:
#                                name  \
# bioguideId
# M001190           Mullin, Markwayne
# W000253     Weicker, Lowell P., Jr.
# E000071                Ellzey, Jake
#
#                                                                                                                                                          terms
# bioguideId
# M001190                      {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2013}, {'chamber': 'Senate', 'startYear': 2023}]}
# W000253     {'item': [{'chamber': 'House of Representatives', 'endYear': 1971, 'startYear': 1969}, {'chamber': 'Senate', 'endYear': 1989, 'startYear': 1973}]}
# E000071                                                                                 {'item': [{'chamber': 'House of Representatives', 'startYear': 2021}]}

# %%
def congress (x,congress_period, chamber):

    terms = ast.literal_eval(x)['item']
    
    for term in terms:

        if term['chamber'] != chamber:
            continue
        
        if 'endYear' not in term.keys() and term['startYear'] < congress_period[1]:
            return True
        
        if 'endYear' in term.keys():
            if term['endYear'] >= congress_period[1] and term['startYear'] <= congress_period[1]:
                return True
            elif term['endYear'] <= congress_period[1] and term['endYear'] > congress_period[0]:
                return True
            elif term['startYear'] <= congress_period[1] and term['startYear'] > congress_period[0]:
                return True
            else:
                continue
    return False

# %%
c = 0
for i in range(0,20,2):
    print(f"Period {2021-i} - {2023-i}")
    senate = df.loc[df['terms'].apply(congress,congress_period=(2021-i,2023-i),chamber='Senate')]
    print(senate.shape,"\n")
# Out:
# Period 2021 - 2023
# (100, 2)
#
# Period 2019 - 2021
# (101, 2)
#
# Period 2017 - 2019
# (105, 2)
#
# Period 2015 - 2017
# (102, 2)
#
# Period 2013 - 2015
# (104, 2)
#
# Period 2011 - 2013
# (106, 2)
#
# Period 2009 - 2011
# (111, 2)
#
# Period 2007 - 2009
# (110, 2)
#
# Period 2005 - 2007
# (104, 2)
#
# Period 2003 - 2005
# (108, 2)

# %%
def years_in_office (x):
    terms = ast.literal_eval(x['terms'])['item']
    
    years_house = 0
    years_senate = 0
    
    for term in terms:
        if 'endYear' not in term.keys():
            end = datetime.date.today().year
        else:
            end = term['endYear']
            
        if term['chamber'] ==  'House of Representatives':
            years_house += end - term['startYear'] + 1
        else:
            years_senate += end - term['startYear'] + 1    
            
    return years_house, years_senate

# %%
current_senate = df.loc[df['terms'].apply(congress,congress_period=(2023,2025),chamber='Senate')]
current_senate
# Out:
#                            name  \
# bioguideId
# M001190       Mullin, Markwayne
# W000800            Welch, Peter
# F000479         Fetterman, John
# S001227           Schmitt, Eric
# V000137            Vance, J. D.
# ...                         ...
# B001277     Blumenthal, Richard
# B001261          Barrasso, John
# B001267      Bennet, Michael F.
# B001230          Baldwin, Tammy
# B001243       Blackburn, Marsha
#
#                                                                                                                                         terms
# bioguideId
# M001190     {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2013}, {'chamber': 'Senate', 'startYear': 2023}]}
# W000800     {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2007}, {'chamber': 'Senate', 'startYear': 2023}]}
# F000479                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
# S001227                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
# V000137                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
# ...                                                                                                                                       ...
# B001277                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2011}]}
# B001261                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2007}]}
# B001267                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2009}]}
# B001230     {'item': [{'chamber': 'House of Representatives', 'endYear': 2013, 'startYear': 1999}, {'chamber': 'Senate', 'startYear': 2013}]}
# B001243     {'item': [{'chamber': 'House of Representatives', 'endYear': 2019, 'startYear': 2003}, {'chamber': 'Senate', 'startYear': 2019}]}
#
# [100 rows x 2 columns]

# %%
years_df = current_senate.apply(lambda row: years_in_office(row), axis=1, result_type='expand')
current_senate[['years_house', 'years_senate']] = years_df
current_senate
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7120/2471478435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_senate[['years_house', 'years_senate']] = years_df
# C:\Users\User\AppData\Local\Temp/ipykernel_7120/2471478435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current_senate[['years_house', 'years_senate']] = years_df
#                            name  \
# bioguideId
# M001190       Mullin, Markwayne
# W000800            Welch, Peter
# F000479         Fetterman, John
# S001227           Schmitt, Eric
# V000137            Vance, J. D.
# ...                         ...
# B001277     Blumenthal, Richard
# B001261          Barrasso, John
# B001267      Bennet, Michael F.
# B001230          Baldwin, Tammy
# B001243       Blackburn, Marsha
#
#                                                                                                                                         terms  \
# bioguideId
# M001190     {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2013}, {'chamber': 'Senate', 'startYear': 2023}]}
# W000800     {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2007}, {'chamber': 'Senate', 'startYear': 2023}]}
# F000479                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
# S001227                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
# V000137                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
# ...                                                                                                                                       ...
# B001277                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2011}]}
# B001261                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2007}]}
# B001267                                                                                  {'item': [{'chamber': 'Senate', 'startYear': 2009}]}
# B001230     {'item': [{'chamber': 'House of Representatives', 'endYear': 2013, 'startYear': 1999}, {'chamber': 'Senate', 'startYear': 2013}]}
# B001243     {'item': [{'chamber': 'House of Representatives', 'endYear': 2019, 'startYear': 2003}, {'chamber': 'Senate', 'startYear': 2019}]}
#
#             years_house  years_senate
# bioguideId
# M001190              11             1
# W000800              17             1
# F000479               0             1
# S001227               0             1
# V000137               0             1
# ...                 ...           ...
# B001277               0            13
# B001261               0            17
# B001267               0            15
# B001230              15            11
# B001243              17             5
#
# [100 rows x 4 columns]

# %%
current_senate.to_csv("C://Users//User//Desktop//congress//data//current_senate.csv",index='bioguideId')

# %%
current_senate = pd.read_csv("C://Users//User//Desktop//congress//data//current_senate.csv")
current_senate.head(3)
# Out:
#   bioguideId               name  \
# 0    M001190  Mullin, Markwayne
# 1    W000800       Welch, Peter
# 2    F000479    Fetterman, John
#
#                                                                                                                                terms  \
# 0  {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2013}, {'chamber': 'Senate', 'startYear': 2023}]}
# 1  {'item': [{'chamber': 'House of Representatives', 'endYear': 2023, 'startYear': 2007}, {'chamber': 'Senate', 'startYear': 2023}]}
# 2                                                                               {'item': [{'chamber': 'Senate', 'startYear': 2023}]}
#
#    years_house  years_senate
# 0           11             1
# 1           17             1
# 2            0             1

# %%
#plt.rcParams["figure.figsize"] = [20, 8]
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,8))
plot_senate = current_senate.copy(deep=True).set_index('name')
plot_senate = plot_senate.sort_values("years_senate")
fig.suptitle("2023 Senate")
ax1.set_title("Most years in Senate")
ax2.set_title("Least years in Senate")
plot_senate[['years_house','years_senate']][:20].plot(kind='barh', stacked=True, grid=True, ax=ax2)
plot_senate[['years_house','years_senate']][80:].plot(kind='barh', stacked=True, grid=True, ax=ax1)
fig.tight_layout()
plt.savefig("C://Users//User//Desktop//congress//images//tenure.png",transparent=True,facecolor='w')

# %% [markdown]
# ### Duration of study: 2011-2021
#
# 3 intervals with **Democratic Senate majority** and Democratic President (2011-2013, 2013-2015, 2021-2023)
#
# 2 intervals with **Republican Senate majority** and Republican President (2017-2019, 2019-2021)
#
# 1 interval with **Republican Senate majority** and Democratic President (2015-2017)

# %%
#Create 2011-2021 "Super-Senate"
#2011-2013 ------> 112th United States Congress
#2019-2021 ------> 116th United States Congress

# %%
super_senate = df.loc[df['terms'].apply(congress,congress_period=(2011,2021),chamber='Senate')]
super_senate
# Out:
#                            name  \
# bioguideId
# C001098               Cruz, Ted
# W000817       Warren, Elizabeth
# W000802     Whitehouse, Sheldon
# Y000064             Young, Todd
# W000779              Wyden, Ron
# ...                         ...
# B000243             Baucus, Max
# A000069        Akaka, Daniel K.
# K000352                Kyl, Jon
# J000177            Johnson, Tim
# H000206             Harkin, Tom
#
#                                                                                                                                                                                                                     terms
# bioguideId
# C001098                                                                                                                                                              {'item': [{'chamber': 'Senate', 'startYear': 2013}]}
# W000817                                                                                                                                                              {'item': [{'chamber': 'Senate', 'startYear': 2013}]}
# W000802                                                                                                                                                              {'item': [{'chamber': 'Senate', 'startYear': 2007}]}
# Y000064                                                                                 {'item': [{'chamber': 'House of Representatives', 'endYear': 2017, 'startYear': 2011}, {'chamber': 'Senate', 'startYear': 2017}]}
# W000779                                                                                 {'item': [{'chamber': 'House of Representatives', 'endYear': 1996, 'startYear': 1981}, {'chamber': 'Senate', 'startYear': 1996}]}
# ...                                                                                                                                                                                                                   ...
# B000243                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1979, 'startYear': 1975}, {'chamber': 'Senate', 'endYear': 2014, 'startYear': 1979}]}
# A000069                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1991, 'startYear': 1977}, {'chamber': 'Senate', 'endYear': 2013, 'startYear': 1990}]}
# K000352     {'item': [{'chamber': 'House of Representatives', 'endYear': 1995, 'startYear': 1987}, {'chamber': 'Senate', 'endYear': 2013, 'startYear': 1995}, {'chamber': 'Senate', 'endYear': 2019, 'startYear': 2018}]}
# J000177                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1997, 'startYear': 1987}, {'chamber': 'Senate', 'endYear': 2015, 'startYear': 1997}]}
# H000206                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1985, 'startYear': 1975}, {'chamber': 'Senate', 'endYear': 2015, 'startYear': 1985}]}
#
# [154 rows x 2 columns]

# %%
super_senate.to_csv("C://Users//User//Desktop//congress//data//super_senate.csv",index='bioguideId')

# %%
super_senate = pd.read_csv("C://Users//User//Desktop//congress//data//super_senate.csv",index_col='bioguideId')

# %%
super_senate
# Out:
#                            name  \
# bioguideId
# C001098               Cruz, Ted
# W000817       Warren, Elizabeth
# W000802     Whitehouse, Sheldon
# Y000064             Young, Todd
# W000779              Wyden, Ron
# ...                         ...
# B000243             Baucus, Max
# A000069        Akaka, Daniel K.
# K000352                Kyl, Jon
# J000177            Johnson, Tim
# H000206             Harkin, Tom
#
#                                                                                                                                                                                                                     terms
# bioguideId
# C001098                                                                                                                                                              {'item': [{'chamber': 'Senate', 'startYear': 2013}]}
# W000817                                                                                                                                                              {'item': [{'chamber': 'Senate', 'startYear': 2013}]}
# W000802                                                                                                                                                              {'item': [{'chamber': 'Senate', 'startYear': 2007}]}
# Y000064                                                                                 {'item': [{'chamber': 'House of Representatives', 'endYear': 2017, 'startYear': 2011}, {'chamber': 'Senate', 'startYear': 2017}]}
# W000779                                                                                 {'item': [{'chamber': 'House of Representatives', 'endYear': 1996, 'startYear': 1981}, {'chamber': 'Senate', 'startYear': 1996}]}
# ...                                                                                                                                                                                                                   ...
# B000243                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1979, 'startYear': 1975}, {'chamber': 'Senate', 'endYear': 2014, 'startYear': 1979}]}
# A000069                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1991, 'startYear': 1977}, {'chamber': 'Senate', 'endYear': 2013, 'startYear': 1990}]}
# K000352     {'item': [{'chamber': 'House of Representatives', 'endYear': 1995, 'startYear': 1987}, {'chamber': 'Senate', 'endYear': 2013, 'startYear': 1995}, {'chamber': 'Senate', 'endYear': 2019, 'startYear': 2018}]}
# J000177                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1997, 'startYear': 1987}, {'chamber': 'Senate', 'endYear': 2015, 'startYear': 1997}]}
# H000206                                                                {'item': [{'chamber': 'House of Representatives', 'endYear': 1985, 'startYear': 1975}, {'chamber': 'Senate', 'endYear': 2015, 'startYear': 1985}]}
#
# [154 rows x 2 columns]

# %% [markdown]
# ### Let's add more data to the super-Senate dataset
#
# - State
# - Party
# - Birth year
#
#
# - Sponsored Legislation count
# - Sponsored Legislation URL
#
#
# - Cosponsored Legislation count
# - Cosponsored Legislation URL

# %%
def enrich_senate(x):
    response = urlopen(f"https://api.congress.gov/v3/member/{x}/?format=json&api_key={API_KEY}")
    response_content = response.read().decode('utf-8')
    responseJson = json.loads(response_content)

    member_info = responseJson.get('member', {})
    state = member_info.get('state')
    birth_year = member_info.get('birthYear')
    sponsored_count = member_info.get('sponsoredLegislation', {}).get('count')
    sponsored_url = member_info.get('sponsoredLegislation', {}).get('url')
    cosponsored_count = member_info.get('cosponsoredLegislation', {}).get('count')
    cosponsored_url = member_info.get('cosponsoredLegislation', {}).get('url')

    return state, birth_year, sponsored_count, sponsored_url, cosponsored_count, cosponsored_url

# %% [markdown]
# ### Members with more than one party affiliation

# %%
for index, row in super_senate.iterrows():
    response = urlopen(f"https://api.congress.gov/v3/member/{index}/?limit=250&format=json&api_key={API_KEY}")
    response_content = response.read().decode('utf-8')
    responseJson = json.loads(response_content)
    if len(responseJson['member']['partyHistory']) > 1:
        print(row['name'],'\n',responseJson['member']['partyHistory'],'\n\n')
# Out:
# Sinema, Kyrsten
#  [{'endYear': 2023, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 2013}, {'partyAbbreviation': 'I', 'partyName': 'Independent', 'startYear': 2023}]
#
#
# Shelby, Richard C.
#  [{'endYear': 1995, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1979}, {'partyAbbreviation': 'R', 'partyName': 'Republican', 'startYear': 1995}]
#
#
# Lieberman, Joseph I.
#  [{'endYear': 2007, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1989}, {'partyAbbreviation': 'ID', 'partyName': 'Independent Democrat', 'startYear': 2007}]
#
#
# Inouye, Daniel K.
#  [{'endYear': 1973, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1971}, {'endYear': 1971, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1969}, {'endYear': 1969, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1967}, {'endYear': 1967, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1965}, {'endYear': 1965, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1963}, {'endYear': 1963, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1961}, {'endYear': 1961, 'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1959}, {'partyAbbreviation': 'D', 'partyName': 'Democratic', 'startYear': 1973}]

# %% [markdown]
# All members who changed affiliation did so before the duration studied. We can register Lieberman, Joseph I. as a Democrat for the sake of convenience.

# %%
new_columns = super_senate.apply(lambda row: enrich_senate(row.name), axis=1, result_type='expand')

# %%
super_senate[['state', 'birthYear', 'sponsoredLegislation_count', 'sponsoredLegislation_url', \
'cosponsoredLegislation_count', 'cosponsoredLegislation_url']] = new_columns

years_df = super_senate.apply(lambda row: years_in_office(row), axis=1, result_type='expand')
super_senate[['years_house', 'years_senate']] = years_df

super_senate.head(3)
# Out:
#                            name  \
# bioguideId
# C001098               Cruz, Ted
# W000817       Warren, Elizabeth
# W000802     Whitehouse, Sheldon
#
#                                                            terms  \
# bioguideId
# C001098     {'item': [{'chamber': 'Senate', 'startYear': 2013}]}
# W000817     {'item': [{'chamber': 'Senate', 'startYear': 2013}]}
# W000802     {'item': [{'chamber': 'Senate', 'startYear': 2007}]}
#
#                     state birthYear  sponsoredLegislation_count  \
# bioguideId
# C001098             Texas      1970                       765.0
# W000817     Massachusetts      1949                       562.0
# W000802      Rhode Island      1955                       561.0
#
#                                                     sponsoredLegislation_url  \
# bioguideId
# C001098     https://api.congress.gov/v3/member/C001098/sponsored-legislation
# W000817     https://api.congress.gov/v3/member/W000817/sponsored-legislation
# W000802     https://api.congress.gov/v3/member/W000802/sponsored-legislation
#
#             cosponsoredLegislation_count  \
# bioguideId
# C001098                             1577
# W000817                             3447
# W000802                             4053
#
#                                                     cosponsoredLegislation_url  \
# bioguideId
# C001098     https://api.congress.gov/v3/member/C001098/cosponsored-legislation
# W000817     https://api.congress.gov/v3/member/W000817/cosponsored-legislation
# W000802     https://api.congress.gov/v3/member/W000802/cosponsored-legislation
#
#             years_house  years_senate
# bioguideId
# C001098               0            11
# W000817               0            11
# W000802               0            17

# %% [markdown]
# **We drop Chiesa Jeff from our dataset due to no legislative output**

# %%
super_senate[super_senate.isna().any(axis=1)]
# Out:
#                     name  \
# bioguideId
# C001100     Chiesa, Jeff
#
#                                                                             terms  \
# bioguideId
# C001100     {'item': [{'chamber': 'Senate', 'endYear': 2013, 'startYear': 2013}]}
#
#                  state birthYear  sponsoredLegislation_count  \
# bioguideId
# C001100     New Jersey      1965                         NaN
#
#            sponsoredLegislation_url  cosponsoredLegislation_count  \
# bioguideId
# C001100                        None                            16
#
#                                                     cosponsoredLegislation_url  \
# bioguideId
# C001100     https://api.congress.gov/v3/member/C001100/cosponsored-legislation
#
#             years_house  years_senate
# bioguideId
# C001100               0             1

# %%
super_senate.drop(['C001100'], axis=0, inplace=True)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
plot_senate = current_senate.copy(deep=True).set_index('name')
plot_senate = plot_senate.sort_values("years_senate")
fig.suptitle("Senate Productivity")
ax1.set_title("Sponsorship by year")
ax2.set_title("Co-sponsorship by year")

ax1.scatter(super_senate['years_senate'], super_senate['sponsoredLegislation_count'])
m1, b1 = np.polyfit(super_senate['years_senate'], super_senate['sponsoredLegislation_count'], 1)
ax1.plot(super_senate['years_senate'], m1 * super_senate['years_senate'] + b1, color='green')
ax1.set_xlabel("Years in Senate")
ax1.set_ylabel("Number of Bills Sponsored")

ax2.scatter(super_senate['years_senate'], super_senate['cosponsoredLegislation_count'])
m2, b2 = np.polyfit(super_senate['years_senate'], super_senate['cosponsoredLegislation_count'], 1)
ax2.plot(super_senate['years_senate'], m2 * super_senate['years_senate'] + b2, color='green')
ax2.set_xlabel("Years in Senate")
ax2.set_ylabel("Number of Bills Co-sponsored")

fig.tight_layout()
plt.savefig("C://Users//User//Desktop//congress//images//productivity.png", transparent=True, facecolor='w')

print(f"{super_senate['sponsoredLegislation_count'].sum()/super_senate['years_senate'].sum():.2f} bills sponsored per year")
print(f"{super_senate['cosponsoredLegislation_count'].sum()/super_senate['years_senate'].sum():.2f} bills co-sponsored per year")
# Out:
# 46.60 bills sponsored per year
# 196.70 bills co-sponsored per year

# %%
fig = plt.figure(figsize=(10, 10))
plt.scatter(super_senate['sponsoredLegislation_count'], super_senate['cosponsoredLegislation_count'])
plt.xlabel("Number of Bills Sponsored")
plt.ylabel("Number of Bills Co-sponsored")
plt.savefig("C://Users//User//Desktop//congress//images//co_vs_spons.png", transparent=True, facecolor='w')

# %%
super_senate.to_csv("C://Users//User//Desktop//congress//data//super_senate.csv",index='bioguideId')

# %% [markdown]
# ### Now we need to find all bills during the time studied as well their respective sponsors and co-sponsors
#
# We are going to implement a dict of sets with bills filtered in the desired time span

# %%
for index, row in super_senate.iterrows():
    response = urlopen(f"https://api.congress.gov/v3/member/{index}/?limit=250&format=json&api_key={API_KEY}")
    response_content = response.read().decode('utf-8')
    responseJson = json.loads(response_content)
    if len(responseJson['member']['partyHistory']) > 1:
        print(row['name'],'\n',responseJson['member']['partyHistory'],'\n\n')

# %%
response = urlopen(f"https://api.congress.gov/v3/member/W000817/sponsored-legislation?limit=250&format=json&api_key={API_KEY}")
response_content = response.read().decode('utf-8')
responseJson = json.loads(response_content)
responseJson

# %%
responseJson['sponsoredLegislation']
# Out:
# [{'amendmentNumber': '329',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/329?format=json'},
#  {'amendmentNumber': '326',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/326?format=json'},
#  {'amendmentNumber': '328',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/328?format=json'},
#  {'amendmentNumber': '327',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/327?format=json'},
#  {'amendmentNumber': '325',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/325?format=json'},
#  {'amendmentNumber': '323',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/323?format=json'},
#  {'amendmentNumber': '324',
#   'congress': 118,
#   'introducedDate': '2023-07-13',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/118/samdt/324?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-07-12',
#   'latestAction': {'actionDate': '2023-07-12',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '2257',
#   'policyArea': {'name': None},
#   'title': 'A bill to amend the Federal Reserve Act to add additional demographic reporting requirements, to modify the goals of the Federal Reserve System, and for other purposes.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/2257?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-22',
#   'latestAction': {'actionDate': '2023-06-22',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '2171',
#   'policyArea': {'name': None},
#   'title': 'A bill to permit legally married same-sex couples to amend their filing status for tax returns outside the statute of limitations.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/2171?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-20',
#   'latestAction': {'actionDate': '2023-06-20',
#    'text': "Read twice and referred to the Committee on Veterans' Affairs."},
#   'number': '2056',
#   'policyArea': {'name': None},
#   'title': 'A bill to amend title 37, United States Code, to strengthen and expand restrictions on retired members and members of reserve components of the uniformed services accepting employment and compensation from foreign governments, and for other purposes.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/2056?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-20',
#   'latestAction': {'actionDate': '2023-06-20',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2047',
#   'policyArea': {'name': None},
#   'title': 'A bill to amend title 10, United States Code, to create a Department of Defense Military Housing Readiness Council to enhance oversight and accountability for deficiencies in military housing, and for other purposes.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/2047?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-20',
#   'latestAction': {'actionDate': '2023-06-20',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2050',
#   'policyArea': {'name': None},
#   'title': 'A bill to promote ethics and prevent corruption in Department of Defense contracting and other activities, and for other purposes.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/2050?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-20',
#   'latestAction': {'actionDate': '2023-06-20',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2049',
#   'policyArea': {'name': None},
#   'title': 'A bill to prevent price gouging at the Department of Defense.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/2049?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-14',
#   'latestAction': {'actionDate': '2023-06-14',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '1966',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': "Junior Reserve Officers' Training Corps Safety Act of 2023",
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1966?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-08',
#   'latestAction': {'actionDate': '2023-06-08',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '1908',
#   'policyArea': {'name': 'Law'},
#   'title': 'Judicial Ethics and Anti-Corruption Act of 2023',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1908?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-06-01',
#   'latestAction': {'actionDate': '2023-06-01',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '1790',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Failed Bank Executives Clawback Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1790?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-03-29',
#   'latestAction': {'actionDate': '2023-05-17',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '1045',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Failed Bank Executives Clawback Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1045?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-31',
#   'latestAction': {'actionDate': '2023-05-31',
#    'text': 'Referred to the Committee on the Judiciary. (text: CR S1848-1849)'},
#   'number': '230',
#   'policyArea': {'name': 'Civil Rights and Liberties, Minority Issues'},
#   'title': 'A resolution recognizing the 102nd anniversary of the 1921 Tulsa Race Massacre.',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/118/sres/230?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-18',
#   'latestAction': {'actionDate': '2023-06-07',
#    'text': 'Committee on Indian Affairs. Ordered to be reported with an amendment in the nature of a substitute favorably.'},
#   'number': '1723',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Truth and Healing Commission on Indian Boarding School Policies Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1723?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-17',
#   'latestAction': {'actionDate': '2023-05-17',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '1663',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Strengthening Federal Reserve System Accountability Act of 2023',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1663?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-17',
#   'latestAction': {'actionDate': '2023-05-17',
#    'text': "Read twice and referred to the Committee on Veterans' Affairs."},
#   'number': '1633',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'United States Cadet Nurse Corps Service Recognition Act of 2023',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1633?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-15',
#   'latestAction': {'actionDate': '2023-05-15',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '1605',
#   'policyArea': {'name': 'Health'},
#   'title': 'Maternal Health Pandemic Response Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1605?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-09',
#   'latestAction': {'actionDate': '2023-05-09',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '1486',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Presidential Conflicts of Interest Act of 2023',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1486?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-05-01',
#   'latestAction': {'actionDate': '2023-05-01',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '1393',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Sunlight in Workplace Harassment Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1393?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-04-26',
#   'latestAction': {'actionDate': '2023-04-26',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '1317',
#   'policyArea': {'name': 'Health'},
#   'title': 'Anti-Racism in Public Health Act of 2023',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/1317?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-03-15',
#   'latestAction': {'actionDate': '2023-03-15',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '817',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'SVB Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/817?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-03-06',
#   'latestAction': {'actionDate': '2023-03-06',
#    'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S656)'},
#   'number': '94',
#   'policyArea': {'name': 'Health'},
#   'title': 'A resolution memorializing those lost to the COVID-19 pandemic.',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/118/sres/94?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': {'actionDate': '2022-09-29',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '5035',
#   'policyArea': {'name': 'Emergency Management'},
#   'title': 'Housing Survivors of Major Disasters Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5035?format=json'},
#  {'congress': 118,
#   'introducedDate': '2023-02-09',
#   'latestAction': {'actionDate': '2023-02-09',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '388',
#   'policyArea': {'name': 'Families'},
#   'title': 'Child Care for Every Community Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/118/s/388?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-05-12',
#   'latestAction': {'actionDate': '2022-05-12',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '4214',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'Price Gouging Prevention Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4214?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-20',
#   'latestAction': {'actionDate': '2022-12-20',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '5312',
#   'policyArea': {'name': 'Transportation and Public Works'},
#   'title': 'Air Traffic Noise and Pollution Expert Consensus Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5312?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-20',
#   'latestAction': {'actionDate': '2022-12-20',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '5321',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'DIGITAL Reservations Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5321?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-20',
#   'latestAction': {'actionDate': '2022-12-20',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '5322',
#   'policyArea': {'name': 'Health'},
#   'title': 'Medical Innovation Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5322?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-15',
#   'latestAction': {'actionDate': '2022-12-15',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '5284',
#   'policyArea': {'name': 'Health'},
#   'title': 'Maternal Health Pandemic Response Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5284?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-19',
#   'latestAction': {'actionDate': '2022-12-19',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '5299',
#   'policyArea': {'name': 'Crime and Law Enforcement'},
#   'title': 'Gun Violence Prevention and Community Safety Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5299?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-15',
#   'latestAction': {'actionDate': '2022-12-15',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '5267',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Digital Asset Anti-Money Laundering Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5267?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-14',
#   'latestAction': {'actionDate': '2022-12-14',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '5255',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Streamline Pentagon Budgeting Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5255?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-09-28',
#   'latestAction': {'actionDate': '2022-09-28',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '4980',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Consumer Bankruptcy Reform Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4980?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-05',
#   'latestAction': {'actionDate': '2022-12-05',
#    'text': 'Read twice and referred to the Committee on Indian Affairs.'},
#   'number': '5186',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Honoring Promises to Native Nations Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5186?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-06-10',
#   'latestAction': {'actionDate': '2021-06-10',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '2014',
#   'policyArea': {'name': 'Taxation'},
#   'title': 'Refund Equality Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2014?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-20',
#   'latestAction': {'actionDate': '2022-12-20',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '5315',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Anti-Corruption and Public Integrity Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5315?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-09-20',
#   'latestAction': {'actionDate': '2022-09-20',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S4878; text: CR S4861-4862)'},
#   'number': '781',
#   'policyArea': {'name': 'Health'},
#   'title': 'A resolution recognizing the seriousness of polycystic ovary syndrome (PCOS) and expressing support for the designation of September 2022 as "PCOS Awareness Month."',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sres/781?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-12-01',
#   'latestAction': {'actionDate': '2022-12-01',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '5173',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Financial Relief for Civilians Treated at Military Hospitals Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/5173?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-09-30',
#   'latestAction': {'actionDate': '2022-06-22',
#    'text': 'Committee on Indian Affairs. Hearings held.'},
#   'number': '2907',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Truth and Healing Commission on Indian Boarding School Policies Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2907?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-03-16',
#   'latestAction': {'actionDate': '2022-03-16',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3847',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'Prohibiting Anticompetitive Mergers Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3847?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-04-07',
#   'latestAction': {'actionDate': '2022-04-07',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '4043',
#   'policyArea': {'name': 'Health'},
#   'title': 'Delivering Over-the-Counter Hearing Aids Now Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4043?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-07-15',
#   'latestAction': {'actionDate': '2021-07-15',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2371',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Department of Defense Climate Resiliency and Readiness Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2371?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-08-02',
#   'latestAction': {'actionDate': '2022-08-02',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '4742',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Military Housing Readiness Council Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4742?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-10-20',
#   'latestAction': {'actionDate': '2022-09-08',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '3022',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Stop Wall Street Looting Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3022?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-05-05',
#   'latestAction': {'actionDate': '2022-05-05',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '4159',
#   'policyArea': {'name': 'Emergency Management'},
#   'title': 'FEMA Equity Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4159?format=json'},
#  {'amendmentNumber': '6213',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6213?format=json'},
#  {'amendmentNumber': '6160',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6160?format=json'},
#  {'amendmentNumber': '6163',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6163?format=json'},
#  {'amendmentNumber': '6161',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6161?format=json'},
#  {'amendmentNumber': '6162',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6162?format=json'},
#  {'amendmentNumber': '6164',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6164?format=json'},
#  {'amendmentNumber': '6047',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6047?format=json'},
#  {'amendmentNumber': '6045',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6045?format=json'},
#  {'amendmentNumber': '6046',
#   'congress': 117,
#   'introducedDate': '2022-09-29',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/6046?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-07-12',
#   'latestAction': {'actionDate': '2021-07-12',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2314',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Improving Worker Safety in Contracting Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2314?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-07-20',
#   'latestAction': {'actionDate': '2021-07-20',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2402',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'A bill to establish a pilot program to incentivize employee ownership in defense contracting.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2402?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-02-10',
#   'latestAction': {'actionDate': '2022-04-05',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '3631',
#   'policyArea': {'name': 'Congress'},
#   'title': 'Bipartisan Ban on Congressional Stock Ownership Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3631?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-04-27',
#   'latestAction': {'actionDate': '2022-04-27',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '4100',
#   'policyArea': {'name': 'Health'},
#   'title': 'Mamas First Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4100?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-07-11',
#   'latestAction': {'actionDate': '2022-07-11',
#    'text': 'Read twice and referred to the Committee on Rules and Administration.'},
#   'number': '4500',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Youth Voting Rights Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4500?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-03-17',
#   'latestAction': {'actionDate': '2022-09-20',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '3867',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Digital Asset Sanctions Compliance Enhancement Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3867?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-09-13',
#   'latestAction': {'actionDate': '2021-09-13',
#    'text': 'Read twice and referred to the Committee on the Budget.'},
#   'number': '2723',
#   'policyArea': {'name': 'Economics and Public Finance'},
#   'title': 'FAIR Scoring Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2723?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-09-08',
#   'latestAction': {'actionDate': '2022-09-08',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '4803',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Nationwide Right To Unionize Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4803?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-07-26',
#   'latestAction': {'actionDate': '2022-07-26',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '4616',
#   'policyArea': {'name': 'Health'},
#   'title': 'Behavioral Health Coverage Transparency Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4616?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-03-18',
#   'latestAction': {'actionDate': '2022-08-04',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '874',
#   'policyArea': {'name': 'Transportation and Public Works'},
#   'title': 'BUILD GREEN Infrastructure and Jobs Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/874?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-27',
#   'latestAction': {'actionDate': '2022-08-04',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '1925',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Buy Green Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1925?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-07-12',
#   'latestAction': {'actionDate': '2022-07-12',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '4508',
#   'policyArea': {'name': 'Taxation'},
#   'title': 'Tax Filing Simplification Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4508?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-11',
#   'latestAction': {'actionDate': '2021-05-11',
#    'text': 'Read twice and referred to the Committee on Agriculture, Nutrition, and Forestry.'},
#   'number': '1569',
#   'policyArea': {'name': 'Agriculture and Food'},
#   'title': 'Student Food Security Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1569?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-06-15',
#   'latestAction': {'actionDate': '2022-06-15',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '4408',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'Health and Location Data Protection Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4408?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-02-03',
#   'latestAction': {'actionDate': '2022-02-03',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '3582',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Political CRIMES Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3582?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-06-09',
#   'latestAction': {'actionDate': '2022-06-09',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '4374',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Stop Price Gouging the Military Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4374?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-06-13',
#   'latestAction': {'actionDate': '2022-06-13',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '4380',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Military Vehicle Fleet Electrification Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4380?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-07-28',
#   'latestAction': {'actionDate': '2021-07-28',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '2497',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Nondebtor Release Prohibition Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2497?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-07-20',
#   'latestAction': {'actionDate': '2021-07-20',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '2400',
#   'policyArea': {'name': 'Public Lands and Natural Resources'},
#   'title': 'Reconciliation in Place Names Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2400?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-05-19',
#   'latestAction': {'actionDate': '2022-05-19',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '47',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'A joint resolution directing the Federal Trade Commission to investigate and report on anticompetitive practices and violations of antitrust law in the beef packing industry.',
#   'type': 'SJRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sjres/47?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-05-10',
#   'latestAction': {'actionDate': '2022-05-10',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '4177',
#   'policyArea': {'name': 'Law'},
#   'title': 'Judicial Ethics and Anti-Corruption Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4177?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-07-15',
#   'latestAction': {'actionDate': '2021-07-15',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '2368',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Military Housing Oversight and Service Member Protection Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2368?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-04-27',
#   'latestAction': {'actionDate': '2021-04-27',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '1398',
#   'policyArea': {'name': 'Families'},
#   'title': 'Universal Child Care and Early Learning Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1398?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-04-28',
#   'latestAction': {'actionDate': '2022-04-28',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '4108',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Protection of Civilians in Military Operations Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4108?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-04-28',
#   'latestAction': {'actionDate': '2022-04-28',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '4107',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Department of Defense Civilian Harm Transparency Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/4107?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-06-09',
#   'latestAction': {'actionDate': '2021-06-09',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '1989',
#   'policyArea': {'name': 'Crime and Law Enforcement'},
#   'title': 'Enhancing Oversight to End Discrimination in Policing Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1989?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-03-30',
#   'latestAction': {'actionDate': '2022-03-30',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3968',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'CDC Tribal Public Health Security and Preparedness Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3968?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-10-04',
#   'latestAction': {'actionDate': '2021-10-04',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '2926',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'A bill to require certain entities to disclose to the Secretary of Homeland Security ransom payments, and for other purposes.',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2926?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-12-16',
#   'latestAction': {'actionDate': '2021-12-16',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3418',
#   'policyArea': {'name': 'Health'},
#   'title': 'Comprehensive Addiction Resources Emergency Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3418?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-20',
#   'latestAction': {'actionDate': '2021-05-20',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '1731',
#   'policyArea': {'name': 'Health'},
#   'title': 'Medicare Audiologist Access and Services Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1731?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-03-21',
#   'latestAction': {'actionDate': '2022-03-21',
#    'text': 'Read twice and referred to the Committee on Agriculture, Nutrition, and Forestry.'},
#   'number': '3886',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Future of Water Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3886?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-01-05',
#   'latestAction': {'actionDate': '2022-01-05',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3444',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Tribal Medical Supplies Stockpile Access Act of 2022',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3444?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-11-18',
#   'latestAction': {'actionDate': '2021-11-18',
#    'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S8454)'},
#   'number': '457',
#   'policyArea': {'name': 'Health'},
#   'title': 'A resolution expressing support for the designation of November 9, 2021, as "National Microtia and Atresia Awareness Day".',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sres/457?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-03-02',
#   'latestAction': {'actionDate': '2022-03-02',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3734',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Gold Star Families Day Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3734?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-12-19',
#   'latestAction': {'actionDate': '2020-12-19',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '5070',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Anti-Corruption and Public Integrity Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/5070?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-03-03',
#   'latestAction': {'actionDate': '2022-03-03',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3758',
#   'policyArea': {'name': 'Health'},
#   'title': 'SAFE SEX Workers Study Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3758?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-04-19',
#   'latestAction': {'actionDate': '2021-09-14',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '1217',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Climate Risk Disclosure Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1217?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '3851',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'BARR Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3851?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-02-01',
#   'latestAction': {'actionDate': '2022-02-01',
#    'text': 'Submitted in the Senate, considered, and agreed to without amendment and with a preamble by Unanimous Consent. (consideration: CR S456, S461; text: CR S447)'},
#   'number': '502',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'A resolution acknowledging and commemorating the World War II women in the Navy who served in the Women Accepted for Volunteer Emergency Service ("WAVES").',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sres/502?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-02-14',
#   'latestAction': {'actionDate': '2022-02-14',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3641',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Part-Time Worker Bill of Rights Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3641?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-03-10',
#   'latestAction': {'actionDate': '2021-03-10',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '681',
#   'policyArea': {'name': 'Immigration'},
#   'title': 'COVID–19 in Immigration Detention Data Transparency Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/681?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-20',
#   'latestAction': {'actionDate': '2021-05-20',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '1730',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Retirement Savings Lost and Found Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1730?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-08-03',
#   'latestAction': {'actionDate': '2021-08-03',
#    'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S5719)'},
#   'number': '334',
#   'policyArea': {'name': 'Health'},
#   'title': 'A resolution memorializing those impacted by and lost to the COVID-19 virus.',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sres/334?format=json'},
#  {'congress': 117,
#   'introducedDate': '2022-02-14',
#   'latestAction': {'actionDate': '2022-02-14',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3642',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Schedules That Work Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/3642?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-10-07',
#   'latestAction': {'actionDate': '2021-10-07',
#    'text': 'Referred to the Committee on Armed Services. (text: CR S7007)'},
#   'number': '419',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'A resolution acknowledging and commemorating the World War II women in the Navy who served in the Women Accepted for Volunteer Emergency Service ("WAVES").',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sres/419?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-09-29',
#   'latestAction': {'actionDate': '2021-09-29',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '2882',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Bank Merger Review Modernization Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2882?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-04-26',
#   'latestAction': {'actionDate': '2022-02-09',
#    'text': 'Committee on Banking, Housing, and Urban Affairs Subcommittee on Financial Institutions and Consumer Protection. Hearings held.'},
#   'number': '1368',
#   'policyArea': {'name': 'Housing and Community Development'},
#   'title': 'American Housing and Economic Mobility Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1368?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-09-21',
#   'latestAction': {'actionDate': '2021-09-21',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '2776',
#   'policyArea': {'name': 'Health'},
#   'title': 'Keeping Renters Safe Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2776?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-06-23',
#   'latestAction': {'actionDate': '2021-06-23',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '2187',
#   'policyArea': {'name': 'Health'},
#   'title': 'National Biomedical Research Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2187?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-04-19',
#   'latestAction': {'actionDate': '2021-07-28',
#    'text': "Committee on Veterans' Affairs. Ordered to be reported without amendment favorably."},
#   'number': '1220',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'United States Cadet Nurse Corps Service Recognition Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1220?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-03-17',
#   'latestAction': {'actionDate': '2020-03-17',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3514',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Tribal Medical Supplies Stockpile Access Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3514?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-10-06',
#   'latestAction': {'actionDate': '2021-10-06',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '2943',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Ransom Disclosure Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/2943?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-04-26',
#   'latestAction': {'actionDate': '2021-04-26',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '1365',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Extending Tribal Broadband Priority Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1365?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-09-14',
#   'latestAction': {'actionDate': '2020-09-14',
#    'text': "Read twice and referred to the Committee on Veterans' Affairs."},
#   'number': '4566',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Modernizing Notice of Lease Terminations for Servicemembers Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4566?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-10-19',
#   'latestAction': {'actionDate': '2020-10-19',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '4809',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Extending Tribal Broadband Priority Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4809?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-07-27',
#   'latestAction': {'actionDate': '2020-07-27',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '4331',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'DIGITAL Reservations Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4331?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-01-08',
#   'latestAction': {'actionDate': '2020-01-08',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3165',
#   'policyArea': {'name': 'Health'},
#   'title': 'SAFE SEX Workers Study Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3165?format=json'},
#  {'congress': 115,
#   'introducedDate': '2017-06-28',
#   'latestAction': {'actionDate': '2017-06-28',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '1470',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Countering Foreign Interference with Our Armed Forces Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/115/s/1470?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-11-17',
#   'latestAction': {'actionDate': '2021-11-17',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '30',
#   'policyArea': {'name': 'Civil Rights and Liberties, Minority Issues'},
#   'title': 'Original Slavery Remembrance Day Resolution',
#   'type': 'SJRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sjres/30?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-27',
#   'latestAction': {'actionDate': '2021-05-27',
#    'text': 'Read twice and referred to the Committee on Energy and Natural Resources.'},
#   'number': '1921',
#   'policyArea': {'name': 'Energy'},
#   'title': 'National Institutes of Clean Energy Act of 2021',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1921?format=json'},
#  {'amendmentNumber': '3898',
#   'congress': 117,
#   'introducedDate': '2021-10-26',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/3898?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-26',
#   'latestAction': {'actionDate': '2021-05-26',
#    'text': 'Read twice and referred to the Committee on Indian Affairs.'},
#   'number': '1868',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'AI/AN CAPTA',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1868?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-10-28',
#   'latestAction': {'actionDate': '2021-10-28',
#    'text': 'Referred to the Committee on the Judiciary. (text: CR S7465)'},
#   'number': '433',
#   'policyArea': {'name': 'Emergency Management'},
#   'title': 'A resolution expressing support for the designation of October 28, 2021, as "Honoring the Nation\'s First Responders Day".',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/117/sres/433?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-05-24',
#   'latestAction': {'actionDate': '2021-05-24',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '1788',
#   'policyArea': {'name': 'Taxation'},
#   'title': 'Restoring the IRS Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/117/s/1788?format=json'},
#  {'amendmentNumber': '3871',
#   'congress': 117,
#   'introducedDate': '2021-10-25',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/3871?format=json'},
#  {'amendmentNumber': '3899',
#   'congress': 117,
#   'introducedDate': '2021-10-26',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/117/samdt/3899?format=json'},
#  {'congress': 117,
#   'introducedDate': '2021-04-19',
#   'latestAction': {'actionDate': '2021-04-19',
#    'text': 'Read twice and referred to the Committee on Foreign Relations.'},
#   'number': '1219',
#   'policyArea': {'name': 'International Affairs'},
#   'title': 'A bill to establish the policy of the United States regarding the no-first-use of nuclear weapons.',
#   'type': 'S',
# ...
#   'number': '1501',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Blast Pressure Exposure Study Improvement Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/1501?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-25',
#   'latestAction': {'actionDate': '2020-06-25',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '4076',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Removing Confederate Names and Symbols from Our Military Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4076?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-04-29',
#   'latestAction': {'actionDate': '2019-04-29',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '1229',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Military Housing Oversight and Service Member Protection Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/1229?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '3853',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'Price Gouging Prevention Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3853?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-12-18',
#   'latestAction': {'actionDate': '2019-12-18',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3095',
#   'policyArea': {'name': 'Education'},
#   'title': 'AIM HIGH Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3095?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-04-03',
#   'latestAction': {'actionDate': '2019-04-03',
#    'text': "Read twice and referred to the Committee on Veterans' Affairs."},
#   'number': '997',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'United States Cadet Nurse Corps Service Recognition Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/997?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-09-08',
#   'latestAction': {'actionDate': '2020-09-08',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '4533',
#   'policyArea': {'name': 'Health'},
#   'title': 'Anti-Racism in Public Health Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4533?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-09-18',
#   'latestAction': {'actionDate': '2019-09-18',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '2498',
#   'policyArea': {'name': 'Education'},
#   'title': 'Pell Grant Restoration Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/2498?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-07-10',
#   'latestAction': {'actionDate': '2020-11-17',
#    'text': 'Committee on Banking, Housing, and Urban Affairs. Hearings held.'},
#   'number': '2075',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Climate Risk Disclosure Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/2075?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-09-29',
#   'latestAction': {'actionDate': '2020-09-29',
#    'text': 'Read twice and referred to the Committee on Indian Affairs.'},
#   'number': '4752',
#   'policyArea': {'name': 'Native Americans'},
#   'title': 'Truth and Healing Commission on Indian Boarding School Policy Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4752?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-05-16',
#   'latestAction': {'actionDate': '2019-05-16',
#    'text': 'Read twice and referred to the Committee on Armed Services.'},
#   'number': '1503',
#   'policyArea': {'name': 'Armed Forces and National Security'},
#   'title': 'Department of Defense Ethics and Anti-corruption Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/1503?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-09-30',
#   'latestAction': {'actionDate': '2020-09-30',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs. (text: CR S5987)'},
#   'number': '48',
#   'policyArea': {'name': 'Emergency Management'},
#   'title': 'A concurrent resolution expressing support for the designation of October 28, 2020, as "Honoring the Nation\'s First Responders Day".',
#   'type': 'SCONRES',
#   'url': 'https://api.congress.gov/v3/bill/116/sconres/48?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-09-09',
#   'latestAction': {'actionDate': '2019-09-09',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '2446',
#   'policyArea': {'name': 'Health'},
#   'title': 'Medicare Audiologist Access and Services Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/2446?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-05-21',
#   'latestAction': {'actionDate': '2019-05-21',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '1576',
#   'policyArea': {'name': 'Health'},
#   'title': 'Behavioral Health Coverage Transparency Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/1576?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-08-06',
#   'latestAction': {'actionDate': '2020-08-06',
#    'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S5285-5286)'},
#   'number': '670',
#   'policyArea': {'name': 'Health'},
#   'title': 'A resolution recognizing the seriousness of polycystic ovary syndrome (PCOS) and expressing support for the designation of September 2020 as "PCOS Awareness Month".',
#   'type': 'SRES',
#   'url': 'https://api.congress.gov/v3/bill/116/sres/670?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-08-06',
#   'latestAction': {'actionDate': '2020-08-06',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '4464',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Federal Reserve Racial and Economic Equity Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4464?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-01-08',
#   'latestAction': {'actionDate': '2020-01-08',
#    'text': 'Read twice and referred to the Committee on Environment and Public Works.'},
#   'number': '3160',
#   'policyArea': {'name': 'Environmental Protection'},
#   'title': 'Affordable Safe Drinking Water Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3160?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-01-16',
#   'latestAction': {'actionDate': '2020-01-16',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '3212',
#   'policyArea': {'name': 'Housing and Community Development'},
#   'title': 'Public Housing Emergency Response Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3212?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '3856',
#   'policyArea': {'name': 'Housing and Community Development'},
#   'title': 'Public Health Emergency Shelter Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3856?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-07-17',
#   'latestAction': {'actionDate': '2019-07-17',
#    'text': 'Read twice and referred to the Committee on Agriculture, Nutrition, and Forestry.'},
#   'number': '2143',
#   'policyArea': {'name': 'Agriculture and Food'},
#   'title': 'College Student Hunger Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/2143?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-04-03',
#   'latestAction': {'actionDate': '2019-04-03',
#    'text': 'Read twice and referred to the Committee on the Judiciary.'},
#   'number': '1010',
#   'policyArea': {'name': 'Crime and Law Enforcement'},
#   'title': 'Corporate Executive Accountability Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/1010?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-01-16',
#   'latestAction': {'actionDate': '2020-01-16',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '3215',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'Accountable Capitalism Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3215?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-07-17',
#   'latestAction': {'actionDate': '2019-07-17',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '2155',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Stop Wall Street Looting Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/2155?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-29',
#   'latestAction': {'actionDate': '2020-06-29',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '4097',
#   'policyArea': {'name': 'Housing and Community Development'},
#   'title': 'Protecting Renters from Evictions and Fees Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4097?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3849',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Emergency Limitation Periods Extensions for Workers Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3849?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3850',
#   'policyArea': {'name': 'Health'},
#   'title': 'Equitable Data Collection and Disclosure on COVID-19 Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3850?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-18',
#   'latestAction': {'actionDate': '2020-06-18',
#    'text': 'Read twice and referred to the Committee on Commerce, Science, and Transportation.'},
#   'number': '4013',
#   'policyArea': {'name': 'Commerce'},
#   'title': 'Pandemic Anti-Monopoly Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/4013?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '3855',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'CORE Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3855?format=json'},
#  {'amendmentNumber': '1681',
#   'congress': 116,
#   'introducedDate': '2020-06-24',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/116/samdt/1681?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-06-01',
#   'latestAction': {'actionDate': '2020-06-01',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '3858',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'PRICE Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3858?format=json'},
#  {'amendmentNumber': '2415',
#   'congress': 116,
#   'introducedDate': '2020-07-01',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/116/samdt/2415?format=json'},
#  {'amendmentNumber': '1859',
#   'congress': 116,
#   'introducedDate': '2020-06-25',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/116/samdt/1859?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-02-27',
#   'latestAction': {'actionDate': '2020-02-27',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3358',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Part-Time Worker Bill of Rights Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3358?format=json'},
#  {'amendmentNumber': '1860',
#   'congress': 116,
#   'introducedDate': '2020-06-25',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/116/samdt/1860?format=json'},
#  {'amendmentNumber': '1682',
#   'congress': 116,
#   'introducedDate': '2020-06-24',
#   'latestAction': None,
#   'type': None,
#   'url': 'https://api.congress.gov/v3/amendment/116/samdt/1682?format=json'},
#  {'congress': 115,
#   'introducedDate': '2018-08-21',
#   'latestAction': {'actionDate': '2018-08-21',
#    'text': 'Read twice and referred to the Committee on Finance.'},
#   'number': '3357',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Anti-Corruption and Public Integrity Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/115/s/3357?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-02-05',
#   'latestAction': {'actionDate': '2020-02-05',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3255',
#   'policyArea': {'name': 'Labor and Employment'},
#   'title': 'Nationwide Right To Unionize Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3255?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-02-05',
#   'latestAction': {'actionDate': '2019-02-05',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '338',
#   'policyArea': {'name': 'Government Operations and Politics'},
#   'title': 'Transition Team Ethics Improvement Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/338?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-03-17',
#   'latestAction': {'actionDate': '2020-03-17',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '3510',
#   'policyArea': {'name': 'Immigration'},
#   'title': 'Prioritizing Pandemic Prevention Act',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3510?format=json'},
#  {'congress': 116,
#   'introducedDate': '2019-05-07',
#   'latestAction': {'actionDate': '2019-05-07',
#    'text': 'Read twice and referred to the Committee on Banking, Housing, and Urban Affairs.'},
#   'number': '1336',
#   'policyArea': {'name': 'Finance and Financial Sector'},
#   'title': 'Data Breach Prevention and Compensation Act of 2019',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/1336?format=json'},
#  {'congress': 116,
#   'introducedDate': '2020-01-08',
#   'latestAction': {'actionDate': '2020-01-08',
#    'text': 'Read twice and referred to the Committee on Health, Education, Labor, and Pensions.'},
#   'number': '3163',
#   'policyArea': {'name': 'Health'},
#   'title': 'Medical Innovation Act of 2020',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/116/s/3163?format=json'},
#  {'congress': 115,
#   'introducedDate': '2018-06-05',
#   'latestAction': {'actionDate': '2018-06-05',
#    'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs.'},
#   'number': '2996',
#   'policyArea': {'name': 'Emergency Management'},
#   'title': 'Housing Victims of Major Disasters Act of 2018',
#   'type': 'S',
#   'url': 'https://api.congress.gov/v3/bill/115/s/2996?format=json'}]

# %%
response = urlopen(f"https://api.congress.gov/v3/bill/117/sconres?limit=250&format=json&api_key={API_KEY}")
response_content = response.read().decode('utf-8')
responseJson = json.loads(response_content)
responseJson
# Out:
# {'bills': [{'congress': 117,
#    'latestAction': {'actionDate': '2022-12-23',
#     'actionTime': '13:16:31',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '52',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution providing for a correction in the enrollment of H.R. 4373.',
#    'type': 'SCONRES',
#    'updateDate': '2023-02-03',
#    'updateDateIncludingText': '2023-02-03T04:45:55Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/52?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-12-23',
#     'actionTime': '12:38:20',
#     'text': 'Pursuant to the provisions of H. Res. 1531, S. Con. Res. 51 is considered passed House. (text: CR H10074-10075)'},
#    'number': '51',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution providing for a correction in the enrollment of H.R. 2617.',
#    'type': 'SCONRES',
#    'updateDate': '2023-03-08',
#    'updateDateIncludingText': '2023-03-08T19:58:55Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/51?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-12-20',
#     'actionTime': '12:11:03',
#     'text': 'Held at the desk.'},
#    'number': '16',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution commemorating the 30th anniversary of Operation Provide Comfort.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-31',
#    'updateDateIncludingText': '2023-01-31T05:15:39Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/16?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-12-08',
#     'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S7075)'},
#    'number': '50',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing the significance of equal pay and the disparity in wages paid to men as compared to wages paid to Latina women.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T09:03:20Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/50?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-12-07',
#     'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 603.'},
#    'number': '47',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': "A concurrent resolution commending the bravery, courage, and resolve of the women and men of Iran demonstrating in more than 80 cities and risking their safety to speak out against the Iranian regime's human rights abuses.",
#    'type': 'SCONRES',
#    'updateDate': '2023-02-04',
#    'updateDateIncludingText': '2023-02-04T05:17:44Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/47?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-11-28',
#     'text': 'Star Print ordered on the concurrent resolution.'},
#    'number': '46',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution commemorating the 50th anniversary of the Federal Water Pollution Control Act Amendments of 1972, commonly known as the "Clean Water Act".',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-16',
#    'updateDateIncludingText': '2022-12-16T14:02:32Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/46?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-11-17',
#     'text': 'Referred to the Committee on Foreign Relations. (text: CR S6786-6787)'},
#    'number': '49',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': "A concurrent resolution expressing support for the Geneva Consensus Declaration on Promoting Women's Health and Strengthening the Family and urging that the United States be added as a signatory.",
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T08:33:28Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/49?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-09-30',
#     'actionTime': '12:15:04',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '45',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution providing for a correction in the enrollment of H.R. 6833.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T13:18:32Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/45?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-09-29',
#     'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S5561-5562)'},
#    'number': '48',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing the significance of equal pay and the disparity in wages paid to men as compared to wages paid to Black women.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T13:18:32Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/48?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-09-21',
#     'actionTime': '14:46:26',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '44',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution authorizing the use of the rotunda of the Capitol for a ceremony to present the statue of Harry S. Truman from the people of Missouri.',
#    'type': 'SCONRES',
#    'updateDate': '2023-02-24',
#    'updateDateIncludingText': '2023-02-24T14:20:50Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/44?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-07-20',
#     'text': 'Motion to proceed to consideration of measure rejected in Senate by Yea-Nay Vote. 34 - 63. Record Vote Number: 265.'},
#    'number': '43',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution setting forth the congressional budget for the United States Government for fiscal year 2023 and setting forth the appropriate budgetary levels for fiscal years 2024 through 2032.',
#    'type': 'SCONRES',
#    'updateDate': '2022-09-06',
#    'updateDateIncludingText': '2022-09-06T00:42:26Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/43?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-07-13',
#     'actionTime': '15:02:43',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '42',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution authorizing the use of the rotunda of the Capitol on Thursday, July 14, 2022, for the lying in honor of the remains of Hershel Woodrow "Woody" Williams, the last surviving Medal of Honor recipient for acts performed during World War II.',
#    'type': 'SCONRES',
#    'updateDate': '2023-02-09',
#    'updateDateIncludingText': '2023-02-09T05:15:46Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/42?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-06-15',
#     'text': 'Motion to proceed to consideration of measure rejected in Senate by Yea-Nay Vote. 29 - 67. Record Vote Number: 228. (CR S2960)'},
#    'number': '41',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution setting forth the congressional budget for the United States Government for fiscal year 2023 and setting forth the appropriate budgetary levels for fiscal years 2024 through 2032.',
#    'type': 'SCONRES',
#    'updateDate': '2022-10-19',
#    'updateDateIncludingText': '2022-10-19T04:25:15Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/41?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-06-14',
#     'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 415.'},
#    'number': '40',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution welcoming the Prime Minister of Greece to the United States for an address to a joint meeting of Congress.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T17:48:33Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/40?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-05-12',
#     'text': 'Referred to the Committee on the Judiciary. (text: CR S2496)'},
#    'number': '39',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution honoring the 1,000,000 individuals who have died from COVID-19 in the United States.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T16:48:33Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/39?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-05-12',
#     'text': 'Message on Senate action sent to the House.'},
#    'number': '20',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution condemning the October 25, 2021, military coup in Sudan and standing with the people of Sudan.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-02',
#    'updateDateIncludingText': '2023-01-02T06:33:14Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/20?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-05-03',
#     'text': 'Referred to the Committee on Commerce, Science, and Transportation. (text: CR S2283-2284)'},
#    'number': '38',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution declaring a state of emergency due to the Russian invasion of Ukraine, in order to establish a waiver of the minimum tonnage requirements of section 55305 of title 46, United States Code.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T16:48:33Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/38?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-05-02',
#     'text': 'Referred to the Committee on Commerce, Science, and Transportation. (text: CR S2248)'},
#    'number': '37',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution declaring a state of emergency due to the Russian invasion of Ukraine, in order to establish a waiver of the minimum tonnage requirements of section 55305 of title 46, United States Code.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T16:48:33Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/37?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-04-28',
#     'actionTime': '12:12:28',
#     'text': 'Held at the desk.'},
#    'number': '36',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution honoring the life and legacy of Ulysses S. Grant in commemoration of his 200th Birthday.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T23:48:35Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/36?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-03-31',
#     'text': 'Referred to the Committee on the Judiciary.'},
#    'number': '35',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution supporting the goals and ideals of International Transgender Day of Visibility.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T22:48:20Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/35?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-03-22',
#     'text': 'Referred to the Committee on Foreign Relations. (text: CR S1292)'},
#    'number': '34',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution to express the sense of Congress in opposition to the establishment of a new Palestinian consulate or diplomatic mission in Jerusalem.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T22:48:20Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/34?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-03-10',
#     'text': 'Referred to the Committee on the Judiciary. (text: CR S1124)'},
#    'number': '33',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution commending the heroism of Olathe East High School Administrator Dr. Kaleb Stoppel and School Resource Officer Erik Clark in responding to a student armed with a firearm.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T22:48:20Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/33?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-03-08',
#     'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S1064-1065)'},
#    'number': '32',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution expressing support for the recognition of March 10, 2022, as "Abortion Provider Appreciation Day".',
#    'type': 'SCONRES',
#    'updateDate': '2023-04-13',
#    'updateDateIncludingText': '2023-04-13T13:45:25Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/32?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-03-01',
#     'text': 'Read twice and referred to the Committee on Homeland Security and Governmental Affairs. (text: CR S886-887)'},
#    'number': '31',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Transparency in Congress Resolution of 2022',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T22:48:20Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/31?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-03-01',
#     'text': 'Referred to the Committee on Foreign Relations. (text: CR S886)'},
#    'number': '30',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution expressing the sense of Congress that the United Nations should take immediate procedural actions necessary to amend Article 23 of the Charter of the United Nations to remove the Russian Federation as a permanent member of the United Nations Security Council.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T22:48:20Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/30?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-02-17',
#     'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S796)'},
#    'number': '29',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing the need to improve physical access to many federally funded facilities for all people of the United States, particularly people with disabilities.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-29',
#    'updateDateIncludingText': '2022-12-29T21:33:29Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/29?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-01-21',
#     'actionTime': '09:11:40',
#     'text': 'Held at the desk.'},
#    'number': '28',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution expressing the sense of Congress that September 30 should be observed as a national day of remembrance for the Native American children who died while attending a United States Indian boarding school and recognizing, honoring, and supporting the survivors of Indian boarding schools, their families, and their communities.',
#    'type': 'SCONRES',
#    'updateDate': '2023-03-08',
#    'updateDateIncludingText': '2023-03-08T20:12:35Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/28?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-01-13',
#     'text': 'Referred to the Committee on the Judiciary. (text: CR S223)'},
#    'number': '27',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution affirming the importance of religious freedom as a fundamental human right that is essential to a free society and protected for all people of the United States under the Constitution of the United States, and recognizing the 236th anniversary of the enactment of the Virginia Statute for Religious Freedom.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-30',
#    'updateDateIncludingText': '2022-12-30T04:04:46Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/27?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-01-10',
#     'actionTime': '19:11:43',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '26',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution providing for the use of the catafalque situated in the Exhibition Hall of the Capitol Visitor Center in connection with memorial services to be conducted in the rotunda of the Capitol for the Honorable Harry Mason Reid, Jr., a Senator from the State of Nevada.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-30',
#    'updateDateIncludingText': '2022-12-30T04:04:46Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/26?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2022-01-10',
#     'actionTime': '19:10:58',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '25',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution authorizing the use of the rotunda of the Capitol for the lying in state of the remains of the Honorable Harry Mason Reid, Jr., a Senator from the State of Nevada.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-30',
#    'updateDateIncludingText': '2022-12-30T04:04:46Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/25?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-12-20',
#     'actionTime': '10:36:35',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '24',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution directing the Secretary of the Senate to make corrections in the enrollment of the bill S. 1605.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-30',
#    'updateDateIncludingText': '2022-12-30T03:33:59Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/24?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-12-08',
#     'actionTime': '21:51:40',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '23',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution authorizing the use of the rotunda of the Capitol for the lying in state of the remains of the Honorable Robert Joseph Dole, a Senator from the State of Kansas.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-30',
#    'updateDateIncludingText': '2022-12-30T03:33:59Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/23?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-12-08',
#     'actionTime': '21:50:30',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '22',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution providing for the use of the catafalque situated in the Exhibition Hall of the Capitol Visitor Center in connection with memorial services to be conducted in the rotunda of the Capitol for the Honorable Robert Joseph Dole, a Senator from the State of Kansas.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-30',
#    'updateDateIncludingText': '2022-12-30T03:33:59Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/22?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-11-16',
#     'text': 'Referred to the Committee on Rules and Administration. (text: CR S8244)'},
#    'number': '21',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution establishing deadlines for the Joint Committee of Congress on the Library to approve or deny the statue of the Reverend William Franklin "Billy" Graham, Jr., for placement in the National Statuary Hall.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-02',
#    'updateDateIncludingText': '2023-01-02T06:33:13Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/21?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-11-04',
#     'actionTime': '12:28:22',
#     'text': 'Held at the desk.'},
#    'number': '19',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution permitting the use of the rotunda of the Capitol for a ceremony as part of the commemoration of the 100th anniversary of the dedication of the Tomb of the Unknown Soldier.',
#    'type': 'SCONRES',
#    'updateDate': '2023-03-08',
#    'updateDateIncludingText': '2023-03-08T20:12:35Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/19?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-11-01',
#     'text': 'Referred to the Committee on Rules and Administration. (text: CR S7540-7541)'},
#    'number': '18',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'ACCEPT Resolution',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-02',
#    'updateDateIncludingText': '2023-01-02T06:33:15Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/18?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-10-28',
#     'text': 'Referred to the Committee on Foreign Relations. (text: CR S7465-7466)'},
#    'number': '17',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': "A concurrent resolution celebrating the first anniversary of the coalition of signatory countries to the Geneva Consensus Declaration on Promoting Women's Health and Strengthening the Family.",
#    'type': 'SCONRES',
#    'updateDate': '2023-01-01',
#    'updateDateIncludingText': '2023-01-01T23:48:22Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/17?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-09-15',
#     'text': 'Referred to the Committee on Foreign Relations. (text: CR S6528)'},
#    'number': '15',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution expressing the sense of Congress that the withdrawal of Armed Forces from Afghanistan does not undermine or diminish the sacrifice, efforts, and accomplishments of the members of the Armed Forces, diplomats, humanitarians, allies, and partners.',
#    'type': 'SCONRES',
#    'updateDate': '2023-03-08',
#    'updateDateIncludingText': '2023-03-08T20:12:44Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/15?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-08-24',
#     'actionTime': '16:11:53',
#     'text': 'Pursuant to the provisions of H. Res. 601, S. Con. Res. 14 is considered passed House. (text: CR H4372-4384)'},
#    'number': '14',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution setting forth the congressional budget for the United States Government for fiscal year 2022 and setting forth the appropriate budgetary levels for fiscal years 2023 through 2031.',
#    'type': 'SCONRES',
#    'updateDate': '2023-05-11',
#    'updateDateIncludingText': '2023-05-11T15:46:24Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/14?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-08-05',
#     'text': 'Placed on Senate Legislative Calendar under General Orders. Calendar No. 118.'},
#    'number': '13',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution setting forth the congressional budget for the United States Government for fiscal year 2022 and setting forth the appropriate budgetary levels for the fiscal years 2023 through 2031.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-01',
#    'updateDateIncludingText': '2023-01-01T20:17:04Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/13?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-08-03',
#     'text': 'Referred to the Committee on Health, Education, Labor, and Pensions. (text: CR S5720)'},
#    'number': '12',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing the significance of equal pay and the disparity in wages paid to men and to Black women.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-01',
#    'updateDateIncludingText': '2023-01-01T20:17:05Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/12?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-07-29',
#     'text': 'Referred to the Committee on the Budget. (text: CR S5182)'},
#    'number': '11',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'Fiscal State of the Nation Resolution',
#    'type': 'SCONRES',
#    'updateDate': '2023-03-08',
#    'updateDateIncludingText': '2023-03-08T20:12:44Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/11?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-06-24',
#     'text': 'Referred to the Committee on Finance. (text: CR S4788)'},
#    'number': '10',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution expressing the sense of Congress that tax-exempt fraternal benefit societies have historically provided and continue to provide critical benefits to the people and communities of the United States.',
#    'type': 'SCONRES',
#    'updateDate': '2022-12-31',
#    'updateDateIncludingText': '2022-12-31T05:25:43Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/10?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-04-29',
#     'text': 'Referred to the Committee on Commerce, Science, and Transportation. (text: CR S2370-2371)'},
#    'number': '9',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution supporting the Local Radio Freedom Act.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:49:02Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/9?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-04-22',
#     'text': 'Referred to the Committee on Environment and Public Works. (text: CR S2180-2181)'},
#    'number': '8',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing that the climate crisis is disproportionately affecting the health, economic opportunity, and fundamental rights of children, expressing the sense of Congress that renewed leadership by the United States is needed to address the climate crisis, and recognizing the need of the United States to develop a national, comprehensive, and science-based climate recovery plan to phase out fossil fuel emissions, protect and enhance natural sequestration, and put the United States on a path toward stabilizing the climate system.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:49:02Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/8?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-03-01',
#     'text': 'Referred to the Committee on Rules and Administration.'},
#    'number': '7',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution recognizing the heroism of the United States Capitol personnel and journalists during the insurrectionist attack on the United States Capitol on January 6, 2021.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:47:33Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/7?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-02-25',
#     'text': 'Referred to the Committee on the Judiciary. (text: CR S901-902)'},
#    'number': '6',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution urging the establishment of a United States Commission on Truth, Racial Healing, and Transformation.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:46:29Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/6?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-02-05',
#     'actionTime': '14:24:21',
#     'text': 'Pursuant to the provisions of H. Res. 101, S. Con. Res. 5 is considered passed House. (consideration: CR H447-455)'},
#    'number': '5',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution setting forth the congressional budget for the United States Government for fiscal year 2021 and setting forth the appropriate budgetary levels for fiscal years 2022 through 2030.',
#    'type': 'SCONRES',
#    'updateDate': '2023-05-11',
#    'updateDateIncludingText': '2023-05-11T15:46:24Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/5?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-01-28',
#     'text': 'Referred to the Committee on the Judiciary. (text: CR S204-205)'},
#    'number': '4',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution affirming the importance of religious freedom as a fundamental human right that is essential to a free society and protected for all people of the United States under the Constitution of the United States, and recognizing the 235th anniversary of the enactment of the Virginia Statute for Religious Freedom.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:47:27Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/4?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-01-22',
#     'text': 'Referred to the Committee on Rules and Administration. (text: CR S107)'},
#    'number': '3',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution authorizing the use of the rotunda of the Capitol for the lying in state of the remains of the last Medal of Honor recipient of World War II, in order to honor the Greatest Generation and the more than 16,000,000 men and women who served in the Armed Forces of the United States from 1941 to 1945.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:47:27Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/3?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-01-03',
#     'actionTime': '19:25:01',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '2',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution extending the life of the Joint Congressional Committee on Inaugural Ceremonies and authorizing the use of the rotunda and Emancipation Hall of the Capitol by the Joint Congressional Committee on Inaugural Ceremonies in connection with the proceedings and ceremonies conducted for the inauguration of the President-elect and the Vice President-elect of the United States.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:47:27Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/2?format=json'},
#   {'congress': 117,
#    'latestAction': {'actionDate': '2021-01-03',
#     'actionTime': '19:23:26',
#     'text': 'Motion to reconsider laid on the table Agreed to without objection.'},
#    'number': '1',
#    'originChamber': 'Senate',
#    'originChamberCode': 'S',
#    'title': 'A concurrent resolution to provide for the counting on January 6, 2021, of the electoral votes for President and Vice President of the United States.',
#    'type': 'SCONRES',
#    'updateDate': '2023-01-11',
#    'updateDateIncludingText': '2023-01-11T13:47:27Z',
#    'url': 'https://api.congress.gov/v3/bill/117/sconres/1?format=json'}],
#  'pagination': {'count': 52},
#  'request': {'billType': 'sconres',
#   'congress': '117',
#   'contentType': 'application/json',
#   'format': 'json'}}
